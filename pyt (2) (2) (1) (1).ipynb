# %%
import pandas as pd  #imports the pandas library and assigns it to pd
import matplotlib.pyplot as plt  #imports the matplotlib.pyplot visualization library and assigns it to plt
import numpy as np   #imports the NumPy numerical and array library and gives it an alias 'np'
import seaborn as sns  #imports the Seaborn data visualization library and gives it an alias 'sns'.

# %%
# Read the XLSX file and make it a DataFrame
DATA = pd.read_excel('project_table.xlsx', index_col=None) 
DATA.head(11).style\
    .background_gradient(cmap='Greens', subset='AGE')\
    .background_gradient(cmap='Purples', subset='SYS_BP')\
    .background_gradient(cmap='Blues', subset='DIA_BP')\
#used to get the first 11 rows of the DATA and styles them
#applies a green background color gradient to the 'AGE'
#applies a Purple background color gradient to the 'SYS_BP'
#applies a Purple background color gradient to the 'DIA_BP'
# Out:
# <style type="text/css">
# #T_c5c65_row0_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_c5c65_row0_col5 {
#   background-color: #7262ac;
#   color: #f1f1f1;
# }
# #T_c5c65_row0_col6 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_c5c65_row1_col1 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_c5c65_row1_col5 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_c5c65_row1_col6, #T_c5c65_row2_col6, #T_c5c65_row8_col6 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c5c65_row2_col1 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_c5c65_row2_col5 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_c5c65_row3_col1 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_c5c65_row3_col5 {
#   background-color: #b5b5d7;
#   color: #000000;
# }
# #T_c5c65_row3_col6 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_c5c65_row4_col1 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_c5c65_row4_col5 {
#   background-color: #b0afd4;
#   color: #000000;
# }
# #T_c5c65_row4_col6 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_c5c65_row5_col1 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_c5c65_row5_col5 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_c5c65_row5_col6 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_c5c65_row6_col1 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_c5c65_row6_col5 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_c5c65_row6_col6 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_c5c65_row7_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c5c65_row7_col5 {
#   background-color: #7567af;
#   color: #f1f1f1;
# }
# #T_c5c65_row7_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c5c65_row8_col1 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_c5c65_row8_col5 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_c5c65_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c5c65_row9_col5 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_c5c65_row9_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c5c65_row10_col1 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_c5c65_row10_col5 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_c5c65_row10_col6 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_c5c65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5c65_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_c5c65_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_c5c65_level0_col2" class="col_heading level0 col2" >NAME</th>
#       <th id="T_c5c65_level0_col3" class="col_heading level0 col3" >BL_SUGAR</th>
#       <th id="T_c5c65_level0_col4" class="col_heading level0 col4" >HB_LEVEL</th>
#       <th id="T_c5c65_level0_col5" class="col_heading level0 col5" >SYS_BP</th>
#       <th id="T_c5c65_level0_col6" class="col_heading level0 col6" >DIA_BP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5c65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5c65_row0_col0" class="data row0 col0" >101</td>
#       <td id="T_c5c65_row0_col1" class="data row0 col1" >55</td>
#       <td id="T_c5c65_row0_col2" class="data row0 col2" >Beverly Young</td>
#       <td id="T_c5c65_row0_col3" class="data row0 col3" >122</td>
#       <td id="T_c5c65_row0_col4" class="data row0 col4" >12</td>
#       <td id="T_c5c65_row0_col5" class="data row0 col5" >155</td>
#       <td id="T_c5c65_row0_col6" class="data row0 col6" >93</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5c65_row1_col0" class="data row1 col0" >102</td>
#       <td id="T_c5c65_row1_col1" class="data row1 col1" >40</td>
#       <td id="T_c5c65_row1_col2" class="data row1 col2" >John Bartolet</td>
#       <td id="T_c5c65_row1_col3" class="data row1 col3" >149</td>
#       <td id="T_c5c65_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_c5c65_row1_col5" class="data row1 col5" >110</td>
#       <td id="T_c5c65_row1_col6" class="data row1 col6" >74</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5c65_row2_col0" class="data row2 col0" >103</td>
#       <td id="T_c5c65_row2_col1" class="data row2 col1" >45</td>
#       <td id="T_c5c65_row2_col2" class="data row2 col2" >Judith Crawford</td>
#       <td id="T_c5c65_row2_col3" class="data row2 col3" >80</td>
#       <td id="T_c5c65_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_c5c65_row2_col5" class="data row2 col5" >100</td>
#       <td id="T_c5c65_row2_col6" class="data row2 col6" >74</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c5c65_row3_col0" class="data row3 col0" >104</td>
#       <td id="T_c5c65_row3_col1" class="data row3 col1" >53</td>
#       <td id="T_c5c65_row3_col2" class="data row3 col2" >Earl Viray</td>
#       <td id="T_c5c65_row3_col3" class="data row3 col3" >55</td>
#       <td id="T_c5c65_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_c5c65_row3_col5" class="data row3 col5" >122</td>
#       <td id="T_c5c65_row3_col6" class="data row3 col6" >83</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c5c65_row4_col0" class="data row4 col0" >105</td>
#       <td id="T_c5c65_row4_col1" class="data row4 col1" >35</td>
#       <td id="T_c5c65_row4_col2" class="data row4 col2" >Kelley Oroark</td>
#       <td id="T_c5c65_row4_col3" class="data row4 col3" >196</td>
#       <td id="T_c5c65_row4_col4" class="data row4 col4" >11</td>
#       <td id="T_c5c65_row4_col5" class="data row4 col5" >124</td>
#       <td id="T_c5c65_row4_col6" class="data row4 col6" >85</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c5c65_row5_col0" class="data row5 col0" >106</td>
#       <td id="T_c5c65_row5_col1" class="data row5 col1" >62</td>
#       <td id="T_c5c65_row5_col2" class="data row5 col2" >Lonnie Ewell</td>
#       <td id="T_c5c65_row5_col3" class="data row5 col3" >137</td>
#       <td id="T_c5c65_row5_col4" class="data row5 col4" >11</td>
#       <td id="T_c5c65_row5_col5" class="data row5 col5" >126</td>
#       <td id="T_c5c65_row5_col6" class="data row5 col6" >84</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c5c65_row6_col0" class="data row6 col0" >107</td>
#       <td id="T_c5c65_row6_col1" class="data row6 col1" >49</td>
#       <td id="T_c5c65_row6_col2" class="data row6 col2" >Jennifer Sturdivant</td>
#       <td id="T_c5c65_row6_col3" class="data row6 col3" >55</td>
#       <td id="T_c5c65_row6_col4" class="data row6 col4" >12</td>
#       <td id="T_c5c65_row6_col5" class="data row6 col5" >188</td>
#       <td id="T_c5c65_row6_col6" class="data row6 col6" >92</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c5c65_row7_col0" class="data row7 col0" >108</td>
#       <td id="T_c5c65_row7_col1" class="data row7 col1" >69</td>
#       <td id="T_c5c65_row7_col2" class="data row7 col2" >Edward Daniel</td>
#       <td id="T_c5c65_row7_col3" class="data row7 col3" >160</td>
#       <td id="T_c5c65_row7_col4" class="data row7 col4" >10</td>
#       <td id="T_c5c65_row7_col5" class="data row7 col5" >153</td>
#       <td id="T_c5c65_row7_col6" class="data row7 col6" >94</td>
#     </tr>
#     <tr>
#       <th id="T_c5c65_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c5c65_row8_col0" class="data row8 col0" >109</td>
#       <td id="T_c5c65_row8_col1" class="data row8 col1" >28</td>
#       <td id="T_c5c65_row8_col2" class="data row8 col2" >Rita Madrigal</td>
#       <td id="T_c5c65_row8_col3" class="data row8 col3" >130</td>
#       <td id="T_c5c65_row8_col4" class="data row8 col4" >14</td>
#       <td id="T_c5c65_row8_col5" class="data row8 col5" >98</td>
#       <td id="T_c5c65_row8_col6" class="data row8 col6" >74</td>
#     </tr>
#     <tr>
#       <th

# %%
DATA.head()
DATA
 # displays the entire data in a formatted tabular view.
# Out:
#      ID  AGE             NAME  BL_SUGAR  HB_LEVEL  SYS_BP  DIA_BP
# 0   101   55    Beverly Young       122        12     155      93
# 1   102   40    John Bartolet       149        10     110      74
# 2   103   45  Judith Crawford        80        10     100      74
# 3   104   53       Earl Viray        55         5     122      83
# 4   105   35    Kelley Oroark       196        11     124      85
# ..  ...  ...              ...       ...       ...     ...     ...
# 95  196   29     Sarah Thomas       131        11     101      78
# 96  197   20  Monica Killough        95        14     181      92
# 97  198   44     Cheri Vannoy       156         6      80      70
# 98  199   58     Paul Meagher        89        13     150      94
# 99  200   57  Shirley Calleja       140        14     198      99
#
# [100 rows x 7 columns]

# %%
DATA_LIST= DATA.values.tolist() #converts the 'DATA' into a list and sets DATA_LIST equal to it.
DATA_LIST #displays the entire 'DATA_LIST', in the form of a list
# Out:
# [[101, 55, 'Beverly Young', 122, 12, 155, 93],
#  [102, 40, 'John Bartolet', 149, 10, 110, 74],
#  [103, 45, 'Judith Crawford', 80, 10, 100, 74],
#  [104, 53, 'Earl Viray', 55, 5, 122, 83],
#  [105, 35, 'Kelley Oroark', 196, 11, 124, 85],
#  [106, 62, 'Lonnie Ewell', 137, 11, 126, 84],
#  [107, 49, 'Jennifer Sturdivant', 55, 12, 188, 92],
#  [108, 69, 'Edward Daniel', 160, 10, 153, 94],
#  [109, 28, 'Rita Madrigal', 130, 14, 98, 74],
#  [110, 6, 'Clara Rose', 87, 8, 77, 73],
#  [111, 39, 'David Schwenke', 180, 14, 97, 77],
#  [112, 14, 'Madelyn Newton', 125, 5, 100, 78],
#  [113, 38, 'Edwin Montenegro', 172, 12, 175, 99],
#  [114, 57, 'Marcia Walker', 51, 12, 192, 96],
#  [115, 33, 'Mary Bolden', 130, 10, 141, 92],
#  [116, 12, 'Alicia Armstead', 178, 6, 100, 70],
#  [117, 42, 'Shawn Ma', 84, 13, 150, 99],
#  [118, 40, 'Kathleen Back', 95, 4, 136, 85],
#  [119, 27, 'Esther Tinsley', 100, 9, 168, 98],
#  [120, 77, 'Tod Davis', 142, 14, 90, 71],
#  [121, 66, 'Doris Foster', 147, 6, 161, 98],
#  [122, 32, 'Michael Tripp', 162, 11, 165, 98],
#  [123, 68, 'Krystal Maxwell', 64, 9, 174, 90],
#  [124, 33, 'Ruth Bridges', 68, 5, 150, 98],
#  [125, 6, 'Joni Ramos', 79, 8, 147, 91],
#  [126, 36, 'Scott Gioia', 68, 7, 102, 76],
#  [127, 59, 'Carl Bell', 91, 9, 115, 75],
#  [128, 56, 'Bryon Zack', 84, 13, 193, 98],
#  [129, 16, 'Kimberly Brown', 195, 6, 102, 71],
#  [130, 43, 'Jose Mendoza', 145, 8, 113, 76],
#  [131, 53, 'Fannie Cordle', 170, 12, 123, 83],
#  [132, 24, 'Shannon King', 87, 13, 180, 95],
#  [133, 51, 'Frank Meads', 189, 7, 147, 96],
#  [134, 32, 'Richard Sullivan', 149, 4, 193, 93],
#  [135, 21, 'Rosetta Poulin', 93, 13, 152, 90],
#  [136, 38, 'Ruth Warden', 76, 14, 178, 94],
#  [137, 63, 'Maria Patterson', 80, 11, 157, 92],
#  [138, 46, 'Jeff English', 178, 8, 97, 78],
#  [139, 52, 'Janet Wibbens', 91, 4, 180, 95],
#  [140, 30, 'Kristen Zimmerman', 84, 4, 100, 78],
#  [141, 34, 'Toni Phillips', 94, 11, 176, 92],
#  [142, 51, 'Brian Hoyt', 143, 9, 99, 77],
#  [143, 66, 'Betty Dulaney', 186, 8, 124, 84],
#  [144, 26, 'Tara Mandujano', 139, 11, 111, 76],
#  [145, 45, 'George Smykowski', 91, 11, 122, 86],
#  [146, 47, 'Mae Applin', 175, 12, 154, 93],
#  [147, 35, 'Edward Nguyen', 77, 13, 83, 78],
#  [148, 39, 'Barry Chio', 188, 14, 167, 93],
#  [149, 50, 'Arthur Bible', 126, 5, 145, 98],
#  [150, 22, 'Jason Stiefel', 158, 11, 177, 91],
#  [151, 37, 'Donna Brown', 128, 8, 108, 74],
#  [152, 76, 'Maida Thompson', 75, 7, 190, 99],
#  [153, 23, 'Justin Kern', 152, 5, 159, 93],
#  [154, 54, 'Jill Stevens', 117, 9, 166, 94],
#  [155, 17, 'Amber Thompson', 105, 4, 114, 76],
#  [156, 37, 'Gary Mcelroy', 144, 4, 163, 94],
#  [157, 30, 'John Reed', 142, 6, 122, 84],
#  [158, 42, 'Lissette Budge', 143, 7, 90, 76],
#  [159, 75, 'William Ledezma', 139, 8, 104, 73],
#  [160, 49, 'Mary Pate', 129, 10, 178, 93],
#  [161, 54, 'Robert Estes', 158, 5, 105, 76],
#  [162, 50, 'Andrea Andrews', 77, 13, 87, 76],
#  [163, 19, 'Thomas Leal', 195, 8, 136, 88],
#  [164, 20, 'Julia Morgan', 104, 13, 105, 78],
#  [165, 65, 'Richard Thomson', 135, 13, 191, 93],
#  [166, 10, 'Homer Rein', 78, 11, 155, 94],
#  [167, 52, 'Amy Pruitt', 176, 10, 70, 76],
#  [168, 14, 'Michael Clines', 98, 12, 166, 96],
#  [169, 60, 'Helena Amato', 131, 7, 150, 97],
#  [170, 14, 'Marc King', 89, 13, 142, 92],
#  [171, 65, 'Daryl Porter', 68, 4, 170, 97],
#  [172, 42, 'Denice Jeffery', 188, 4, 167, 99],
#  [173, 59, 'Dana Stumbaugh', 172, 4, 199, 99],
#  [174, 54, 'Renea Ray', 120, 14, 125, 85],
#  [175, 79, 'Elmer Barbee', 99, 8, 67, 71],
#  [176, 20, 'Rhea Sansone', 53, 10, 150, 94],
#  [177, 62, 'Jaime Delaney', 67, 11, 73, 77],
#  [178, 68, 'Florence Terry', 152, 14, 134, 88],
#  [179, 6, 'Nicole Holifeild', 109, 7, 129, 85],
#  [180, 36, 'Terry Schumann', 159, 6, 175, 97],
#  [181, 72, 'Rebecca Anderson', 78, 13, 147, 93],
#  [182, 37, 'Althea Strother', 110, 13, 104, 76],
#  [183, 16, 'Ronald Goodermote', 172, 12, 99, 76],
#  [184, 58, 'Lloyd Ferry', 119, 12, 125, 85],
#  [185, 8, 'Malissa Snider', 85, 5, 141, 98],
#  [186, 35, 'Caitlin Butts', 164, 10, 97, 73],
#  [187, 23, 'Donna Williams', 154, 14, 154, 99],
#  [188, 64, 'Michael Galloway', 190, 11, 167, 96],
#  [189, 41, 'Dorothy Norton', 74, 11, 163, 93],
#  [190, 7, 'Joseph Kenny', 190, 6, 105, 78],
#  [191, 9, 'Janet Fowler', 158, 8, 93, 70],
#  [192, 63, 'Leslie Sherrod', 143, 12, 156, 97],
#  [193, 37, 'Malissa Johnson', 121, 12, 153, 91],
#  [194, 71, 'Annie Lowery', 78, 14, 192, 94],
#  [195, 11, 'Ruby Snell', 67, 9, 178, 100],
#  [196, 29, 'Sarah Thomas', 131, 11, 101, 78],
#  [197, 20, 'Monica Killough', 95, 14, 181, 92],
#  [198, 44, 'Cheri Vannoy', 156, 6, 80, 70],
#  [199, 58, 'Paul Meagher', 89, 13, 150, 94],
#  [200, 57, 'Shirley Calleja', 140, 14, 198, 99]]

# %%
#defines the function with the name create_generation list with the parameter age_list and sets the three variables under18 adult and senior to 0
def create_generation_list (age_list):
    under18 = 0  
    adult = 0 
    senior = 0
    #iterates through the list and compares the elements in the list to values
    for i in age_list:
        if i <= 18:#if the element in the list is less than or equal to 18 add 1 to under18
            under18+=1
        elif i <= 59:#if the element in the list is less than or equal to 59 add 1 to adult
            adult+=1
        else:
            senior+=1#if the element in the list anyting other than the 
         

        
        
        
    age_count = [under18 , adult, senior]  #stores the values of under18, adult, and senior in the age_count list
    return age_count#returns the list age_count

# %%
 AGE = []#sets AGE to an empty list
for row in DATA_LIST:
    AGE.append (row[1])#stores the values from the age section of our table to the list AGE
    
age_counting = create_generation_list (AGE)#the list age we created with the values added is then used as the argument and stored in the variable age_counting
print(age_counting)#the values are displayed using the print function
# Out:
# [15, 66, 19]

# %%
my_gen_list = create_generation_list (AGE)
#calling a function called create_generation_list with the 'AGE' variable as an argument represented as my_gen_list
my_array= np.array(AGE)# Converting the data to an array
mylabels = ["Adult", "Under 18", "Senior"] #creates a list called 'mylabels' with 3 categories for the pie chart
myexplode = [0.15, 0.15, 0] 
#creates a list 'myexplode' and based of the parameters, it explodes/seperates the category from the pie chart

plt.pie(my_gen_list, labels = mylabels, explode = myexplode)
#plt.pie is a function used to create the pie chart. 
#It takes 'my_gen_list' as the data printed, 'mylables' as the label for each slice
#myexplode is used to explode the distance of each slice

plt.legend(loc = 'center right', bbox_to_anchor=(1,0,0.5,1))
#adds a legend to the pie chart. The loc is use to specify the position and bbox_to_anchor adjusts the position
plt.show() #used to display the pie chart

# %%
def blood_presure_categorize (systolic_bp, diastolic_bp): #defines function with parameters systolic_bp and diastolic 
#sorts the systolic_bp and diastolic_bp setting bp_type to either normal, elevated, or hypertension
#by comparing them with other values    

    if systolic_bp < 120 and diastolic_bp<80:
            bp_type = 'Normal'
    elif systolic_bp >=120 and systolic_bp <= 139 and diastolic_bp>=80 and diastolic_bp<=89:
            bp_type = 'Elevated'
    elif systolic_bp >= 140 and diastolic_bp>=90:
            bp_type = 'Hypertension'
    else:
        bp_type = 'unknown'



    return bp_type #returns the the bp_type

# %%
BPS = [] #initlizes empty lists
BPD = []
BP_CAT = []

for row in DATA_LIST:
    BPS.append (row[5])#stores the 5th row of DATA_LIST in BPS
    BPD.append (row[6])#stores the 6th row of DATA_LIST in BPD



for i in range (len(BPS)): #iterates through BPS and BPD lists
    bpc = blood_presure_categorize (BPS[i], BPD[i]) #stores the retured values from the B.P.C function in the bpc variable 
    BP_CAT.append(bpc) #stores the bp_type values in the list BP_CaT
    print (i, "--", bpc) #displays the values using the print function
# Out:
# 0 -- Hypertension
# 1 -- Normal
# 2 -- Normal
# 3 -- Elevated
# 4 -- Elevated
# 5 -- Elevated
# 6 -- Hypertension
# 7 -- Hypertension
# 8 -- Normal
# 9 -- Normal
# 10 -- Normal
# 11 -- Normal
# 12 -- Hypertension
# 13 -- Hypertension
# 14 -- Hypertension
# 15 -- Normal
# 16 -- Hypertension
# 17 -- Elevated
# 18 -- Hypertension
# 19 -- Normal
# 20 -- Hypertension
# 21 -- Hypertension
# 22 -- Hypertension
# 23 -- Hypertension
# 24 -- Hypertension
# 25 -- Normal
# 26 -- Normal
# 27 -- Hypertension
# 28 -- Normal
# 29 -- Normal
# 30 -- Elevated
# 31 -- Hypertension
# 32 -- Hypertension
# 33 -- Hypertension
# 34 -- Hypertension
# 35 -- Hypertension
# 36 -- Hypertension
# 37 -- Normal
# 38 -- Hypertension
# 39 -- Normal
# 40 -- Hypertension
# 41 -- Normal
# 42 -- Elevated
# 43 -- Normal
# 44 -- Elevated
# 45 -- Hypertension
# 46 -- Normal
# 47 -- Hypertension
# 48 -- Hypertension
# 49 -- Hypertension
# 50 -- Normal
# 51 -- Hypertension
# 52 -- Hypertension
# 53 -- Hypertension
# 54 -- Normal
# 55 -- Hypertension
# 56 -- Elevated
# 57 -- Normal
# 58 -- Normal
# 59 -- Hypertension
# 60 -- Normal
# 61 -- Normal
# 62 -- Elevated
# 63 -- Normal
# 64 -- Hypertension
# 65 -- Hypertension
# 66 -- Normal
# 67 -- Hypertension
# 68 -- Hypertension
# 69 -- Hypertension
# 70 -- Hypertension
# 71 -- Hypertension
# 72 -- Hypertension
# 73 -- Elevated
# 74 -- Normal
# 75 -- Hypertension
# 76 -- Normal
# 77 -- Elevated
# 78 -- Elevated
# 79 -- Hypertension
# 80 -- Hypertension
# 81 -- Normal
# 82 -- Normal
# 83 -- Elevated
# 84 -- Hypertension
# 85 -- Normal
# 86 -- Hypertension
# 87 -- Hypertension
# 88 -- Hypertension
# 89 -- Normal
# 90 -- Normal
# 91 -- Hypertension
# 92 -- Hypertension
# 93 -- Hypertension
# 94 -- Hypertension
# 95 -- Normal
# 96 -- Hypertension
# 97 -- Normal
# 98 -- Hypertension
# 99 -- Hypertension

# %%
# Your data
x=BPS
y=BPD
# Create the scatter plot using seasborns sns.scatterplot function. 
#The 'x', & 'y' variables specify the data for the x and y axis
#hue is set to the different categories
#alpaha sets the transparency levels of the points 
#s sets the size of the markers 
#palette gives each category a color
sns.scatterplot(x=x, y=y, hue=BP_CAT, alpha=0.5, s=100, palette=['red', 'green', 'orange'])

# Customize the plot
plt.title("Systolic vs Diastolic")
plt.ylabel("Diastolic Blood Pressure")
plt.xlabel("Systolic Blood Pressure")

# Move the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# Show the plot
plt.show()

# %%
import pandas as pd
DATA = pd.read_excel('project_table.xlsx') 
HB_lvl= []
NAME = []

#defining the variable the hemoglobin level and the people's name
#Use the bracket to initialize the list

i = 0

#the index starts the beginning

for row in DATA_LIST:
    HB_lvl.append(row[4])
    NAME.append(row[2])
    
#creating the list that reads from the hemoglobin list in row 4 
#and the people's name in row 2

while i < len(HB_lvl):
    
#creates the while loop statement that 
#reads the length of the hemoglobin list

    if HB_lvl[i]<12:
        split_name = NAME[i].split()
        print('HB level =', HB_lvl[i], f"gm/dL ({split_name[1]} {split_name[0][0]}.)")
        i += 1
        
#if the hemoglobin level is less than 12
#then it will split the name that will print out
#full last name and only first initial of the first name

    else:
        i += 1
        
#if condition does not statisfy then it will move on the next list
# the i += 1 stop the while loop going infinite by adding 1
# Out:
# HB level = 10 gm/dL (Bartolet J.)
# HB level = 10 gm/dL (Crawford J.)
# HB level = 5 gm/dL (Viray E.)
# HB level = 11 gm/dL (Oroark K.)
# HB level = 11 gm/dL (Ewell L.)
# HB level = 10 gm/dL (Daniel E.)
# HB level = 8 gm/dL (Rose C.)
# HB level = 5 gm/dL (Newton M.)
# HB level = 10 gm/dL (Bolden M.)
# HB level = 6 gm/dL (Armstead A.)
# HB level = 4 gm/dL (Back K.)
# HB level = 9 gm/dL (Tinsley E.)
# HB level = 6 gm/dL (Foster D.)
# HB level = 11 gm/dL (Tripp M.)
# HB level = 9 gm/dL (Maxwell K.)
# HB level = 5 gm/dL (Bridges R.)
# HB level = 8 gm/dL (Ramos J.)
# HB level = 7 gm/dL (Gioia S.)
# HB level = 9 gm/dL (Bell C.)
# HB level = 6 gm/dL (Brown K.)
# HB level = 8 gm/dL (Mendoza J.)
# HB level = 7 gm/dL (Meads F.)
# HB level = 4 gm/dL (Sullivan R.)
# HB level = 11 gm/dL (Patterson M.)
# HB level = 8 gm/dL (English J.)
# HB level = 4 gm/dL (Wibbens J.)
# HB level = 4 gm/dL (Zimmerman K.)
# HB level = 11 gm/dL (Phillips T.)
# HB level = 9 gm/dL (Hoyt B.)
# HB level = 8 gm/dL (Dulaney B.)
# HB level = 11 gm/dL (Mandujano T.)
# HB level = 11 gm/dL (Smykowski G.)
# HB level = 5 gm/dL (Bible A.)
# HB level = 11 gm/dL (Stiefel J.)
# HB level = 8 gm/dL (Brown D.)
# HB level = 7 gm/dL (Thompson M.)
# HB level = 5 gm/dL (Kern J.)
# HB level = 9 gm/dL (Stevens J.)
# HB level = 4 gm/dL (Thompson A.)
# HB level = 4 gm/dL (Mcelroy G.)
# HB level = 6 gm/dL (Reed J.)
# HB level = 7 gm/dL (Budge L.)
# HB level = 8 gm/dL (Ledezma W.)
# HB level = 10 gm/dL (Pate M.)
# HB level = 5 gm/dL (Estes R.)
# HB level = 8 gm/dL (Leal T.)
# HB level = 11 gm/dL (Rein H.)
# HB level = 10 gm/dL (Pruitt A.)
# HB level = 7 gm/dL (Amato H.)
# HB level = 4 gm/dL (Porter D.)
# HB level = 4 gm/dL (Jeffery D.)
# HB level = 4 gm/dL (Stumbaugh D.)
# HB level = 8 gm/dL (Barbee E.)
# HB level = 10 gm/dL (Sansone R.)
# HB level = 11 gm/dL (Delaney J.)
# HB level = 7 gm/dL (Holifeild N.)
# HB level = 6 gm/dL (Schumann T.)
# HB level = 5 gm/dL (Snider M.)
# HB level = 10 gm/dL (Butts C.)
# HB level = 11 gm/dL (Galloway M.)
# HB level = 11 gm/dL (Norton D.)
# HB level = 6 gm/dL (Kenny J.)
# HB level = 8 gm/dL (Fowler J.)
# HB level = 9 gm/dL (Snell R.)
# HB level = 11 gm/dL (Thomas S.)
# HB level = 6 gm/dL (Vannoy C.)

# %%
import pandas as pd
DATA = pd.read_excel('project_table.xlsx') 
BL_S= []
NAME = []

#defining the variable the blood sugar level and the people's name
#Use the bracket to initialize the list

i = 0

#the index starts the beginning

for row in DATA_LIST:
    BL_S.append(row[3])
    NAME.append(row[2])
    
#creating the list that reads from the blood sugar level list in row 3 
#and the people's name in row 2

while i < len(BL_S):
    
#creates the while loop statement that 
#reads the length of the blood sugar level list

    if BL_S[i]>100:
        split_name = NAME[i].split()
        print('Sugar level =', BL_S[i], f"gm/dL ({split_name[1]} {split_name[0][0]}.)")
        i += 1
        
#if the sugar blood level is more than 100
#then it will split the name that will print out
#full last name and only first initial of the first name

    else:
        i += 1
#if condition does not statisfy then it will move on the next list
# the i += 1 stop the while loop going infinite by adding 1
# Out:
# Sugar level = 122 gm/dL (Young B.)
# Sugar level = 149 gm/dL (Bartolet J.)
# Sugar level = 196 gm/dL (Oroark K.)
# Sugar level = 137 gm/dL (Ewell L.)
# Sugar level = 160 gm/dL (Daniel E.)
# Sugar level = 130 gm/dL (Madrigal R.)
# Sugar level = 180 gm/dL (Schwenke D.)
# Sugar level = 125 gm/dL (Newton M.)
# Sugar level = 172 gm/dL (Montenegro E.)
# Sugar level = 130 gm/dL (Bolden M.)
# Sugar level = 178 gm/dL (Armstead A.)
# Sugar level = 142 gm/dL (Davis T.)
# Sugar level = 147 gm/dL (Foster D.)
# Sugar level = 162 gm/dL (Tripp M.)
# Sugar level = 195 gm/dL (Brown K.)
# Sugar level = 145 gm/dL (Mendoza J.)
# Sugar level = 170 gm/dL (Cordle F.)
# Sugar level = 189 gm/dL (Meads F.)
# Sugar level = 149 gm/dL (Sullivan R.)
# Sugar level = 178 gm/dL (English J.)
# Sugar level = 143 gm/dL (Hoyt B.)
# Sugar level = 186 gm/dL (Dulaney B.)
# Sugar level = 139 gm/dL (Mandujano T.)
# Sugar level = 175 gm/dL (Applin M.)
# Sugar level = 188 gm/dL (Chio B.)
# Sugar level = 126 gm/dL (Bible A.)
# Sugar level = 158 gm/dL (Stiefel J.)
# Sugar level = 128 gm/dL (Brown D.)
# Sugar level = 152 gm/dL (Kern J.)
# Sugar level = 117 gm/dL (Stevens J.)
# Sugar level = 105 gm/dL (Thompson A.)
# Sugar level = 144 gm/dL (Mcelroy G.)
# Sugar level = 142 gm/dL (Reed J.)
# Sugar level = 143 gm/dL (Budge L.)
# Sugar level = 139 gm/dL (Ledezma W.)
# Sugar level = 129 gm/dL (Pate M.)
# Sugar level = 158 gm/dL (Estes R.)
# Sugar level = 195 gm/dL (Leal T.)
# Sugar level = 104 gm/dL (Morgan J.)
# Sugar level = 135 gm/dL (Thomson R.)
# Sugar level = 176 gm/dL (Pruitt A.)
# Sugar level = 131 gm/dL (Amato H.)
# Sugar level = 188 gm/dL (Jeffery D.)
# Sugar level = 172 gm/dL (Stumbaugh D.)
# Sugar level = 120 gm/dL (Ray R.)
# Sugar level = 152 gm/dL (Terry F.)
# Sugar level = 109 gm/dL (Holifeild N.)
# Sugar level = 159 gm/dL (Schumann T.)
# Sugar level = 110 gm/dL (Strother A.)
# Sugar level = 172 gm/dL (Goodermote R.)
# Sugar level = 119 gm/dL (Ferry L.)
# Sugar level = 164 gm/dL (Butts C.)
# Sugar level = 154 gm/dL (Williams D.)
# Sugar level = 190 gm/dL (Galloway M.)
# Sugar level = 190 gm/dL (Kenny J.)
# Sugar level = 158 gm/dL (Fowler J.)
# Sugar level = 143 gm/dL (Sherrod L.)
# Sugar level = 121 gm/dL (Johnson M.)
# Sugar level = 131 gm/dL (Thomas S.)
# Sugar level = 156 gm/dL (Vannoy C.)
# Sugar level = 140 gm/dL (Calleja S.)
